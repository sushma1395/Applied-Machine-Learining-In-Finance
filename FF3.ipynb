# %%
import pandas as pd
import pandas_datareader.data as web
import datetime, re, copy
import numpy as np
import statsmodels.formula.api as sm

df_nvda =pd.read_csv("NVDA.csv", decimal = ',')

# %%
df_nvda.head()
# Out:
#        Date       Open      Close       High        Low    Volume
# 0  4-Jan-16  32.290001  32.369999  32.580002  32.040001   8951900
# 1  5-Jan-16      32.98  32.889999  33.439999       32.5  12256800
# 2  6-Jan-16  32.349998  31.530001       32.5      31.16  11233600
# 3  7-Jan-16      30.74  30.280001  30.950001  29.879999  16132600
# 4  8-Jan-16      30.67  29.629999  30.700001      29.57   9961800

# %%
df_nvda.dtypes
# Out:
# Date      object
# Open      object
# Close     object
# High      object
# Low       object
# Volume    object
# dtype: object

# %%
df_nvda['Open'] = df_nvda['Open'].astype(float)

# %%
df_nvda.dtypes
# Out:
# Date       object
# Open      float64
# Close      object
# High       object
# Low        object
# Volume     object
# dtype: object

# %%
df_nvda['Date']= pd.to_datetime(df_nvda['Date']) 
df_nvda.head()
# Out:
#         Date       Open      Close       High        Low    Volume
# 0 2016-01-04  32.290001  32.369999  32.580002  32.040001   8951900
# 1 2016-01-05  32.980000  32.889999  33.439999       32.5  12256800
# 2 2016-01-06  32.349998  31.530001       32.5      31.16  11233600
# 3 2016-01-07  30.740000  30.280001  30.950001  29.879999  16132600
# 4 2016-01-08  30.670000  29.629999  30.700001      29.57   9961800

# %%
df_nvda
df_nvda = df_nvda.set_index('Date')
df_nvda.head(3)
# Out:
#                  Open      Close       High        Low    Volume
# Date
# 2016-01-04  32.290001  32.369999  32.580002  32.040001   8951900
# 2016-01-05  32.980000  32.889999  33.439999       32.5  12256800
# 2016-01-06  32.349998  31.530001       32.5      31.16  11233600

# %%
open = df_nvda['Open']
rets = open.pct_change()*100
rets = pd.DataFrame(rets)
rets.rename( columns={"Open":"open"}, inplace=True)

# %%
rets.head()
# Out:
#                 open
# Date
# 2016-01-04       NaN
# 2016-01-05  2.136881
# 2016-01-06 -1.910255
# 2016-01-07 -4.976810
# 2016-01-08 -0.227716

# %%
# get fama/french factor data
# http://mba.tuck.dartmouth.edu/pages/faculty/ken.french/data_library.html
three_fac = web.DataReader("F-F_Research_Data_Factors_daily", "famafrench")
f = copy.copy(three_fac[0])
f.rename( columns={c:re.sub(r'[0-9\-\s]','',c) for c in f.columns}, inplace=True)
f.head()
# Out:
#             MktRF   SMB   HML   RF
# Date
# 2010-01-04   1.69  0.58  1.12  0.0
# 2010-01-05   0.31 -0.59  1.21  0.0
# 2010-01-06   0.13 -0.24  0.52  0.0
# 2010-01-07   0.40  0.09  0.94  0.0
# 2010-01-08   0.33  0.40  0.01  0.0

# %%
m = pd.merge(rets,f,left_index=True,right_index=True)

# %%
m.head()
# Out:
#                 open  MktRF   SMB   HML   RF
# Date
# 2016-01-04       NaN  -1.59 -0.83  0.53  0.0
# 2016-01-05  2.136881   0.12 -0.22  0.01  0.0
# 2016-01-06 -1.910255  -1.35 -0.12 -0.01  0.0
# 2016-01-07 -4.976810  -2.44 -0.29  0.08  0.0
# 2016-01-08 -0.227716  -1.11 -0.47 -0.03  0.0

# %%
# excess returns
m['open_e'] = m.open-m.RF
train = m[:499]
valid = m[500:878]

# %%
# ols regression
result = sm.ols( formula = "open_e ~ MktRF + SMB + HML", data=train).fit()

# intercept = alpha
print(result.params)
print (result.summary())
# Out:
# Intercept    0.367306
# MktRF        0.231769
# SMB          0.620173
# HML          0.320641
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 open_e   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.023
# Method:                 Least Squares   F-statistic:                     4.920
# Date:                Sun, 15 Dec 2019   Prob (F-statistic):            0.00223
# Time:                        19:11:32   Log-Likelihood:                -1173.0
# No. Observations:                 498   AIC:                             2354.
# Df Residuals:                     494   BIC:                             2371.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3673      0.115      3.182      0.002       0.141       0.594
# MktRF          0.2318      0.180      1.285      0.199      -0.123       0.586
# SMB            0.6202      0.246      2.516      0.012       0.136       1.104
# HML            0.3206      0.213      1.506      0.133      -0.098       0.739
# ==============================================================================
# Omnibus:                       52.157   Durbin-Watson:                   2.124
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              286.441
# Skew:                          -0.204   Prob(JB):                     6.31e-63
# Kurtosis:                       6.693   Cond. No.                         2.29
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y = result.predict(valid)

# %%
print(y)
# Out:
# Date
# 2017-12-27    0.237350
# 2017-12-28    0.505541
# 2017-12-29    0.055559
# 2018-01-02    0.717030
# 2018-01-03    0.194847
# 2018-01-04    0.380358
# 2018-01-05    0.226048
# 2018-01-08    0.334559
# 2018-01-09    0.172396
# 2018-01-10    0.580466
# 2018-01-11    1.381331
# 2018-01-12    0.388730
# 2018-01-16   -0.385250
# 2018-01-17    0.526986
# 2018-01-18   -0.064659
# 2018-01-19    1.059931
# 2018-01-22    0.290019
# 2018-01-23    0.399307
# 2018-01-24   -0.027711
# 2018-01-25    0.331845
# 2018-01-26    0.079742
# 2018-01-29    0.121637
# 2018-01-30    0.135341
# 2018-01-31   -0.076204
# 2018-02-01    0.596597
# 2018-02-02   -0.194330
# 2018-02-05   -0.268749
# 2018-02-06    0.364324
# 2018-02-07    0.675004
# 2018-02-08    0.179163
#                 ...
# 2019-05-17   -0.192001
# 2019-05-20    0.327323
# 2019-05-21    0.721150
# 2019-05-22   -0.231290
# 2019-05-23   -0.458086
# 2019-05-24    0.829886
# 2019-05-28    0.161588
# 2019-05-29    0.176385
# 2019-05-30   -0.030197
# 2019-05-31   -0.110578
# 2019-06-03    0.984390
# 2019-06-04    1.131896
# 2019-06-05   -0.390932
# 2019-06-06   -0.141004
# 2019-06-07    0.233406
# 2019-06-10    0.467698
# 2019-06-11    0.367427
# 2019-06-12    0.258844
# 2019-06-13    0.893933
# 2019-06-14   -0.064209
# 2019-06-17    0.434084
# 2019-06-18    0.793302
# 2019-06-19    0.320512
# 2019-06-20    0.276570
# 2019-06-21    0.017112
# 2019-06-24   -0.233958
# 2019-06-25    0.588305
# 2019-06-26    0.386730
# 2019-06-27    1.351953
# 2019-06-28    1.123612
# Length: 378, dtype: float64
